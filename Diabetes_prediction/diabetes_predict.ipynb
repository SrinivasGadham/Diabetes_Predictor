# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install sklearn
# Out:
# Requirement already satisfied: pandas in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplotlib in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: seaborn in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (0.11.2)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: matplotlib>=2.2 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: sklearn in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.8.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nithin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.1)
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
y=df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x=df.drop(['Outcome'],axis='columns')
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=7)
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 289            5      108             72             43       75  36.1
# 328            2      102             86             36      120  45.5
# 394            4      158             78              0        0  32.9
# 321            3      112             74             30        0  31.6
# 326            1      122             64             32      156  35.1
# ..           ...      ...            ...            ...      ...   ...
# 579            2      197             70             99        0  34.7
# 502            6        0             68             41        0  39.0
# 537            0       57             60              0        0  21.7
# 196            1      105             58              0        0  24.3
# 175            8      179             72             42      130  32.7
#
#      DiabetesPedigreeFunction  Age
# 289                     0.263   33
# 328                     0.127   23
# 394                     0.803   31
# 321                     0.197   25
# 326                     0.692   30
# ..                        ...  ...
# 579                     0.575   62
# 502                     0.727   41
# 537                     0.735   67
# 196                     0.187   21
# 175                     0.719   36
#
# [614 rows x 8 columns]

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 353            1       90             62             12       43  27.2
# 236            7      181             84             21      192  35.9
# 323           13      152             90             33       29  26.8
# 98             6       93             50             30       64  28.7
# 701            6      125             78             31        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 153            1      153             82             42      485  40.6
# 392            1      131             64             14      415  23.7
# 308            0      128             68             19      180  30.5
# 70             2      100             66             20       90  32.9
# 513            2       91             62              0        0  27.3
#
#      DiabetesPedigreeFunction  Age
# 353                     0.580   24
# 236                     0.586   51
# 323                     0.731   43
# 98                      0.356   23
# 701                     0.565   49
# ..                        ...  ...
# 153                     0.687   23
# 392                     0.389   21
# 308                     1.391   25
# 70                      0.867   28
# 513                     0.525   22
#
# [154 rows x 8 columns]

# %%
y_train
# Out:
# 289    0
# 328    1
# 394    1
# 321    1
# 326    1
#       ..
# 579    1
# 502    1
# 537    0
# 196    0
# 175    1
# Name: Outcome, Length: 614, dtype: int64

# %%
y_test
# Out:
# 353    0
# 236    1
# 323    1
# 98     0
# 701    1
#       ..
# 153    0
# 392    0
# 308    1
# 70     1
# 513    0
# Name: Outcome, Length: 154, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_predict=lr.predict(x_test)

for i in range(len(y_predict)):
    if y_predict[i]<0.5:
        y_predict[i]=0
    else:
        y_predict[i]=1

print("The first five predicted values are:")
print(y_predict[0:5])
print("The first five test values are:")
print(np.array(y_test[0:5]))
# Out:
# The first five predicted values are:
# [0. 1. 1. 0. 0.]
# The first five test values are:
# [0 1 1 0 1]

# %%
lr.coef_
# Out:
# array([ 0.02125018,  0.00550138, -0.00233104,  0.00043653, -0.00019935,
#         0.01410673,  0.18992038,  0.00192842])

# %%
lr.intercept_
# Out:
# -0.8369410878179921

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_predict=knn.predict(x_test)
print("The first five predicted values are:")
print(y_predict[0:5])
print("The first five test values are:")
print(np.array(y_test[0:5]))
knn.score(x_test,y_test)
# Out:
# The first five predicted values are:
# [0 1 0 0 0]
# The first five test values are:
# [0 1 1 0 1]
# 0.6883116883116883

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_predict=knn.predict(x_test)
print("The first five predicted values are:")
print(y_predict[0:5])
print("The first five test values are:")
print(np.array(y_test[0:5]))
knn.score(x_test,y_test)
# Out:
# The first five predicted values are:
# [0 1 0 0 0]
# The first five test values are:
# [0 1 1 0 1]
# 0.7077922077922078

# %%
from sklearn import metrics
matrix=metrics.confusion_matrix(y_predict,y_test)
sns.heatmap(matrix,annot=True,cmap='Blues',fmt='0.1f')
plt.xlabel('Predicted values')
plt.ylabel('Test values')
plt.title('Confusion Matrix for KNeighborsClassifier')
plt.show()
